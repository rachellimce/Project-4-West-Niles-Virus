# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Executive-Summary" data-toc-modified-id="Executive-Summary-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Executive Summary</a></span></li><li><span><a href="#Data-Dictionary" data-toc-modified-id="Data-Dictionary-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Dictionary</a></span></li><li><span><a href="#Contents" data-toc-modified-id="Contents-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Contents</a></span></li><li><span><a href="#File-imports" data-toc-modified-id="File-imports-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>File imports</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Data-Cleaning---Train" data-toc-modified-id="Data-Cleaning---Train-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Data Cleaning - Train</a></span></li><li><span><a href="#Data-Cleaning---Weather" data-toc-modified-id="Data-Cleaning---Weather-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Data Cleaning - Weather</a></span></li><li><span><a href="#Data-Cleaning---Spray" data-toc-modified-id="Data-Cleaning---Spray-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Data Cleaning - Spray</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#EDA---Train" data-toc-modified-id="EDA---Train-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>EDA - Train</a></span><ul class="toc-item"><li><span><a href="#Total-Sample-records-across-Year,-Month" data-toc-modified-id="Total-Sample-records-across-Year,-Month-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Total Sample records across Year, Month</a></span></li><li><span><a href="#Samples-with-WNV-present-across-Year,-Month" data-toc-modified-id="Samples-with-WNV-present-across-Year,-Month-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Samples with WNV present across Year, Month</a></span></li><li><span><a href="#Total-number-of-Mosquitos-collected-across-Year,-Month" data-toc-modified-id="Total-number-of-Mosquitos-collected-across-Year,-Month-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Total number of Mosquitos collected across Year, Month</a></span></li><li><span><a href="#Mosquito-Species-spread" data-toc-modified-id="Mosquito-Species-spread-7.1.4"><span class="toc-item-num">7.1.4&nbsp;&nbsp;</span>Mosquito Species spread</a></span></li><li><span><a href="#No-of-Traps-and-Wnv-present" data-toc-modified-id="No-of-Traps-and-Wnv-present-7.1.5"><span class="toc-item-num">7.1.5&nbsp;&nbsp;</span>No of Traps and Wnv present</a></span></li><li><span><a href="#Visualizing-Location-of-Traps-and-presence-of-Wnv" data-toc-modified-id="Visualizing-Location-of-Traps-and-presence-of-Wnv-7.1.6"><span class="toc-item-num">7.1.6&nbsp;&nbsp;</span>Visualizing Location of Traps and presence of Wnv</a></span></li><li><span><a href="#Counting-total-Mosquito-in-a-Trap" data-toc-modified-id="Counting-total-Mosquito-in-a-Trap-7.1.7"><span class="toc-item-num">7.1.7&nbsp;&nbsp;</span>Counting total Mosquito in a Trap</a></span></li></ul></li><li><span><a href="#EDA---Weather" data-toc-modified-id="EDA---Weather-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>EDA - Weather</a></span><ul class="toc-item"><li><span><a href="#Average-Temperature-Across-Year" data-toc-modified-id="Average-Temperature-Across-Year-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Average Temperature Across Year</a></span></li><li><span><a href="#Average-Rainfall-Across-Year" data-toc-modified-id="Average-Rainfall-Across-Year-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Average Rainfall Across Year</a></span></li><li><span><a href="#Average-Relative-Humidity-Across-Year" data-toc-modified-id="Average-Relative-Humidity-Across-Year-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Average Relative Humidity Across Year</a></span></li></ul></li><li><span><a href="#EDA---Spray-data" data-toc-modified-id="EDA---Spray-data-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>EDA - Spray data</a></span></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Feature-Engineering---Train" data-toc-modified-id="Feature-Engineering---Train-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Feature Engineering - Train</a></span><ul class="toc-item"><li><span><a href="#Feature-Consolidation:-species" data-toc-modified-id="Feature-Consolidation:-species-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Feature Consolidation: <code>species</code></a></span></li><li><span><a href="#New-Feature:-closest_station" data-toc-modified-id="New-Feature:-closest_station-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>New Feature: <code>closest_station</code></a></span></li><li><span><a href="#New-Feature:-row_count" data-toc-modified-id="New-Feature:-row_count-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>New Feature: <code>row_count</code></a></span></li><li><span><a href="#New-Feature:-intensity_acc" data-toc-modified-id="New-Feature:-intensity_acc-8.1.4"><span class="toc-item-num">8.1.4&nbsp;&nbsp;</span>New Feature: <code>intensity_acc</code></a></span></li></ul></li><li><span><a href="#Feature-Engineering---Weather" data-toc-modified-id="Feature-Engineering---Weather-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Feature Engineering - Weather</a></span><ul class="toc-item"><li><span><a href="#New-Feature:-daytime" data-toc-modified-id="New-Feature:-daytime-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>New Feature: <code>daytime</code></a></span></li><li><span><a href="#New-Feature:-rhumidity" data-toc-modified-id="New-Feature:-rhumidity-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>New Feature: <code>rhumidity</code></a></span></li><li><span><a href="#New-Feature:-Rolling-averages-tavg,-resultspeed,-dewpoint,-tmax,-tmin,-preciptotal,-rhumidity" data-toc-modified-id="New-Feature:-Rolling-averages-tavg,-resultspeed,-dewpoint,-tmax,-tmin,-preciptotal,-rhumidity-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>New Feature: Rolling averages <code>tavg</code>, <code>resultspeed</code>, <code>dewpoint</code>, <code>tmax</code>, <code>tmin</code>, <code>preciptotal</code>, <code>rhumidity</code></a></span></li><li><span><a href="#Feature-Consolidation-to-Train" data-toc-modified-id="Feature-Consolidation-to-Train-8.2.4"><span class="toc-item-num">8.2.4&nbsp;&nbsp;</span>Feature Consolidation to Train</a></span></li><li><span><a href="#One-Hot-Encoding" data-toc-modified-id="One-Hot-Encoding-8.2.5"><span class="toc-item-num">8.2.5&nbsp;&nbsp;</span>One Hot Encoding</a></span></li></ul></li></ul></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Oversampling-to-tackle-imbalanced-classes" data-toc-modified-id="Oversampling-to-tackle-imbalanced-classes-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Oversampling to tackle imbalanced classes</a></span></li><li><span><a href="#Evaluation-metrics-to-optimise-for" data-toc-modified-id="Evaluation-metrics-to-optimise-for-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Evaluation metrics to optimise for</a></span></li><li><span><a href="#Baseline-score" data-toc-modified-id="Baseline-score-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Baseline score</a></span></li><li><span><a href="#Set-up-X-and-y" data-toc-modified-id="Set-up-X-and-y-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Set up X and y</a></span></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Logistic regression</a></span></li><li><span><a href="#Support-Vector-Machine" data-toc-modified-id="Support-Vector-Machine-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Support Vector Machine</a></span></li><li><span><a href="#Bagging-Classifier" data-toc-modified-id="Bagging-Classifier-9.8"><span class="toc-item-num">9.8&nbsp;&nbsp;</span>Bagging Classifier</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-9.9"><span class="toc-item-num">9.9&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#ExtraTrees" data-toc-modified-id="ExtraTrees-9.10"><span class="toc-item-num">9.10&nbsp;&nbsp;</span>ExtraTrees</a></span></li><li><span><a href="#AdaBoost" data-toc-modified-id="AdaBoost-9.11"><span class="toc-item-num">9.11&nbsp;&nbsp;</span>AdaBoost</a></span></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-9.12"><span class="toc-item-num">9.12&nbsp;&nbsp;</span>Gradient Boosting</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-9.13"><span class="toc-item-num">9.13&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Summary-of-Performance" data-toc-modified-id="Summary-of-Performance-9.14"><span class="toc-item-num">9.14&nbsp;&nbsp;</span>Summary of Performance</a></span></li></ul></li></ul></div>

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 4: Kaggle Competition - Data and EDA
#
# - Consolidated Project Notebook

# %% [markdown]
# ## Problem Statement
#
# ---

# %% [markdown]
# ## Executive Summary
#
# ---

# %% [markdown]
# ## Data Dictionary
#
# ---

# %% [markdown]
# | Feature                | Variable type | Datatype | Dataset            | Description                                                                    |
# |------------------------|---------------|----------|--------------------|--------------------------------------------------------------------------------|
# | Id                     | Norminal      | int64    | test               |  the id of the record                                                          |
# | Date                   | datetime      | datetime | train, test        | date that the WNV test is performed                                            |
# | Address                | Norminal      | object   | train and test     | approximate address of the location of trap                                    |
# | Species                | Norminal      | object   | train and test     | species of mosquito                                                            |
# | Block                  | Norminal      | int64    | train and test     | block number of address                                                        |
# | Street                 | Norminal      | object   | train and test     | Street name                                                                    |
# | Trap                   | Norminal      | object   | train and test     | Id of the trap                                                                 |
# | AddressNumberAndStreet | Norminal      | object   | train and test     | approximate address returned from GeoCoder                                     |
# | Latitude               | continuous    | float64  | train and test     | Latitude  returned from GeoCoder                                               |
# | Longitude              | continuous    | float64  | train and test     | Longitude returned from GeoCoder                                               |
# | AddressAccuracy        | Norminal      | int64    | train and test     | accuracy returned from GeoCoder                                                |
# | NumMosquitos           | discrete      | int64    | train and test     | number of mosquitoes caught in this trap                                       |
# | WnvPresent             | discrete      | int64    | train and test     | 1 means WNV is present, and 0 means not present.                               |
# | Station                | discrete      | int64    | weather            | Station 1 or 2 where weather data is collected                                 |
# | Date                   | datetime      | datetime | weather            | Date of weather record                                                         |
# | Tmax                   | discrete      | int64    | weather            | Max temperature in Fahrenheit                                                  |
# | Tmin                   | discrete      | int64    | weather            | Min temperature in Fahrenheit                                                  |
# | Tavg                   | continuous    | float64  | weather            | Avg temperature in Fahrenheit                                                  |
# | Depart                 | discrete      | float64  | weather            | The difference from normal temperatures for the last 30yrs                     |
# | DewPoint               | discrete      | int64    | weather            | Dew Point temperature                                                          |
# | WetBulb                | discrete      | int64    | weather            | Web Bulb temperature                                                           |
# | Heat                   | continuous    | float64  | weather            | Difference between daily avg temperature and 65 Deg F                          |
# | Cool                   | continuous    | float64  | weather            | Difference between daily avg temperature and 65 Deg F                          |
# | Sunrise                | datetime      | datetime | weather            | Sunrise timing                                                                 |
# | Sunset                 | datetime      | datetime | weather            | Sunset timing                                                                  |
# | CodeSum                | norminal      | object   | weather            | Weather Phenomena                                                              |
# | Depth                  | continuous    | float64  | weather            | Snow inches                                                                    |
# | Water1                 | continuous    | float64  | weather            | Snow/Ice on ground                                                             |
# | SnowFall               | continuous    | float64  | weather            | Snowfall in inches                                                             |
# | PrecipTotal            | continuous    | float64  | weather            | Rainfall and melted snow (inches)                                              |
# | StnPressure            | continuous    | float64  | weather            | Avg Station Pressure                                                           |
# | SeaLevel               | continuous    | float64  | weather            | Avg Sea level Presure                                                          |
# | ResultSpeed            | continuous    | float64  | weather            | Resultant Wind Speed                                                           |
# | ResultDir              | continuous    | int64    | weather            | Resultant Wind Direction                                                       |
# | AvgSpeed               | continuous    | float64  | weather            | Avg WInd Speed                                                                 |
# | Date                   | datetime      | datetime | spray              | Date of the spray                                                              |
# | Time                   | datetime      | datetime | spray              | Time of the spray                                                              |
# | Latitude               | continuous    | float64  | spray              | Latitude of the spray                                                          |
# | Longitude              | continuous    | float64  | spray              | Latitude of the spray                                                          |
# | year                   | discrete      | int64    | engineered feature | year corresponding in train data                                               |
# | month                  | discrete      | int64    | engineered feature | month corresponding in train data                                              |
# | weekofyear             | discrete      | int64    | engineered feature | week of the year corresponding in train data                                   |
# | yearmonth              | norminal      | object   | engineered feature | yearmonth string corresponding in train data                                   |
# | weekday                | discrete      | int64    | engineered feature | weekday corresponding in train data                                            |
# | closest_station        | discrete      | int64    | engineered feature | the closer weather station to each trap                                        |
# | row_count              | discrete      | int64    | engineered feature | number of "duplicate" rowsto get an estimate for nummosquitos                  |
# | daytime                | discrete      | int32    | engineered feature | total number of minutes from Sunrise to Sunset                                 |
# | rhumidity              | continuous    | float64  | engineered feature | relative humidity derived from dewpoint and tavg                               |
# | tavg_7                 | continuous    | float64  | engineered feature | Rolling temp averages for 7,days based on lifecycle of mosquitos               |
# | tavg_10                | continuous    | float64  | engineered feature | Rolling temp averages for 10 days based on lifecycle of mosquitos              |
# | tavg_14                | continuous    | float64  | engineered feature | Rolling temp averages for 14 days based on lifecycle of mosquitos              |
# | tavg_30                | continuous    | float64  | engineered feature | Rolling temp averages for 30 days                                              |
# | tavg_60                | continuous    | float64  | engineered feature | Rolling temp averages for 60 days                                              |
# | tavg_90                | continuous    | float64  | engineered feature | Rolling temp averages for 90 days                                              |
# | resultspeed_7          | continuous    | float64  | engineered feature | Rolling wind speed averages for 7,days based on lifecycle of mosquitos         |
# | resultspeed_10         | continuous    | float64  | engineered feature | Rolling wind speed  averages for 10 days based on lifecycle of mosquitos       |
# | resultspeed_14         | continuous    | float64  | engineered feature | Rolling wind speed  averages for 14 days based on lifecycle of mosquitos       |
# | resultspeed_30         | continuous    | float64  | engineered feature | Rolling wind speed  averages for 30 days                                       |
# | resultspeed_60         | continuous    | float64  | engineered feature | Rolling wind speed  averages for 60 days                                       |
# | resultspeed_90         | continuous    | float64  | engineered feature | Rolling wind speed  averages for 90 days                                       |
# | dewpoint_7             | continuous    | float64  | engineered feature | Rolling dewpoint averages for 7,days based on lifecycle of mosquitos           |
# | dewpoint_10            | continuous    | float64  | engineered feature | Rolling dewpoint averages for 10 days based on lifecycle of mosquitos          |
# | dewpoint_14            | continuous    | float64  | engineered feature | Rolling dewpoint averages for 14 days based on lifecycle of mosquitos          |
# | dewpoint_30            | continuous    | float64  | engineered feature | Rolling dewpoint averages for 30 days                                          |
# | dewpoint_60            | continuous    | float64  | engineered feature | Rolling dewpoint averages for 60 days                                          |
# | dewpoint_90            | continuous    | float64  | engineered feature | Rolling dewpoint averages for 90 days                                          |
# | rhumidity_7            | continuous    | float64  | engineered feature | Rolling relative humidity averages for 7,days based on lifecycle of mosquitos  |
# | rhumidity_10           | continuous    | float64  | engineered feature | Rolling relative humidity averages for 10 days based on lifecycle of mosquitos |
# | rhumidity_14           | continuous    | float64  | engineered feature | Rolling relative humidity averages for 14 days based on lifecycle of mosquitos |
# | rhumidity_30           | continuous    | float64  | engineered feature | Rolling relative humidity averages for 30 days                                 |
# | rhumidity_60           | continuous    | float64  | engineered feature | Rolling relative humidity averages for 60 days                                 |
# | rhumidity_90           | continuous    | float64  | engineered feature | Rolling relative humidity averages for 90 days                                 |
# | tmax_7                 | continuous    | float64  | engineered feature | Rolling max temp averages for 7,days based on lifecycle of mosquitos           |
# | tmax_10                | continuous    | float64  | engineered feature | Rolling max  temp averages for 10 days based on lifecycle of mosquitos         |
# | tmax_14                | continuous    | float64  | engineered feature | Rolling max temp averages for 14 days based on lifecycle of mosquitos          |
# | tmax_30                | continuous    | float64  | engineered feature | Rolling max  temp averages for 30 days                                         |
# | tmax_60                | continuous    | float64  | engineered feature | Rolling max temp averages for 60 days                                          |
# | tmax_90                | continuous    | float64  | engineered feature | Rolling max temp averages for 90 days                                          |
# | tmin_7                 | continuous    | float64  | engineered feature | Rolling min temp averages for 7,days based on lifecycle of mosquitos           |
# | tmin_10                | continuous    | float64  | engineered feature | Rolling min  temp averages for 10 days based on lifecycle of mosquitos         |
# | tmin_14                | continuous    | float64  | engineered feature | Rolling min temp averages for 14 days based on lifecycle of mosquitos          |
# | tmin_30                | continuous    | float64  | engineered feature | Rolling min  temp averages for 30 days                                         |
# | tmin_60                | continuous    | float64  | engineered feature | Rolling min temp averages for 60 days                                          |
# | tmin_90                | continuous    | float64  | engineered feature | Rolling min temp averages for 90 days                                          |
# | preciptotal_7          | continuous    | float64  | engineered feature | Rolling preciptotal averages for 7,days based on lifecycle of mosquitos        |
# | preciptotal_10         | continuous    | float64  | engineered feature | Rolling preciptotal averages for 10 days based on lifecycle of mosquitos       |
# | preciptotal_14         | continuous    | float64  | engineered feature | Rolling preciptotal averages for 14 days based on lifecycle of mosquitos       |
# | preciptotal_30         | continuous    | float64  | engineered feature | Rolling preciptotal averages for 30 days                                       |
# | preciptotal_60         | continuous    | float64  | engineered feature | Rolling preciptotal averages for 60 days                                       |
# | preciptotal_90         | continuous    | float64  | engineered feature | Rolling preciptotal averages for 90 days                                       |

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# ## File imports
#
# ---

# %%
# Standard Imports
import pandas as pd
pd.set_option('max_columns', 500) 
pd.set_option('max_rows', 500) 
pd.options.display.float_format = "{:,.3f}".format
import numpy as np

# Visualization Imports
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
# sns.set_style("whitegrid")

# Additional Imports
from datetime import datetime
from datetime import timedelta
import geopy.distance
import time

# Modeling imports
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score, auc, classification_report, accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from xgboost import XGBClassifier
from yellowbrick.features import FeatureImportances

from sklearn.svm import SVC

# %% [markdown]
# ## Data Cleaning
#
# ---

# %%
def basic_eda(df, df_name='DATA SET DETAILS'):
    """
    Function to do display the basic eda upon reading data to:
    - find the shape (rows, cols)
    - Total observations
    - Duplicated rows if any
    - percent of the duplicated rows
    
    Takes in Arguements:
    - df - the dataframe/data set
    - df name - Name of the data set to display
    """
    print(df_name.upper())
    print('**********************************************')
    #print shape of df in rows and cols
    print(f"Rows: {df.shape[0]} \t Columns: {df.shape[1]}")
    print('==============================================')
    
    print()
    #print info of the df
    print(f'{df_name}.info()')
    print('----------------------------------------------')
    print(df.info())
    print('==============================================')
    
    #print null columsn df
    print(f'{df_name}.null()')
    print('----------------------------------------------')
    print(f"{df.isnull().sum()}")
    print('==============================================')
    
    print(f"Total null rows: {df.isnull().sum().sum()}")
    print(f"Percentage null rows: {round(df.isnull().sum().sum() / df.shape[0] * 100, 2)}%")
    print()
    
    print(f"Total duplicate rows: {df[df.duplicated(keep=False)].shape[0]}")
    print(f"Percentage dupe rows: {round(df[df.duplicated(keep=False)].shape[0] / df.shape[0] * 100, 2)}%")
    print()
    
    #print(df.dtypes)
    print('**********************************************')

# %% [markdown]
# ### Data Cleaning - Train
#
# - Changed column names to lowercase.
# - Transformed `date` to datetime format and created `year`, `month`, `weekofyear`, `yearmonth`, and `weekday`
# - Dropped redundant Columns: `Address`, `Block`, `Street`, and `AddressNumberAndStreet`

# %%
# Import train dataset
train = pd.read_csv('https://raw.githubusercontent.com/zixinlee/GA-data-science/master/West-nile-virus/data/train.csv')

# %%
# Call EDA function
basic_eda(train, df_name='train.csv Data Set')
# Out:
# TRAIN.CSV DATA SET
# **********************************************
# Rows: 10506 	 Columns: 12
# ...
#
# train.csv Data Set.info()
# ----------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    10506 non-null  object
#  1   Address                 10506 non-null  object
#  2   Species                 10506 non-null  object
#  3   Block                   10506 non-null  int64
#  4   Street                  10506 non-null  object
#  5   Trap                    10506 non-null  object
#  6   AddressNumberAndStreet  10506 non-null  object
#  7   Latitude                10506 non-null  float64
#  8   Longitude               10506 non-null  float64
#  9   AddressAccuracy         10506 non-null  int64
#  10  NumMosquitos            10506 non-null  int64
# ...

# %% [markdown]
# **Observations**
# - 12 features
# - 10506 observations
# - 6 numerical data (Block, Latitude, Longtitude, AddressAccuracy, NumMosquitos, WnvPresent)
# - 6 object data (Date, Address, Species, Street, Trap,  AddressNumberAndStreet)
# - no Null values observed
# - There are 813 records of duplications, assuming to be due to multiple samples of 50 collected from the same trap, with same  species and Wnv status detected in the sample group

# %% [markdown]
# ---

# %% [markdown]
# We will proceed by:
#  - Changing all column names to lower case
#  - Converting the 'date' column to datetime format
#  - Dropping redundant location columns

# %%
# make all column names lowercase
train.columns = train.columns.str.lower()

# %%
# convert `date` to datetime datatype
train['date'] = pd.to_datetime(train['date'])

# create new datetime element columns
train['year'] = train.date.dt.year
train['month'] = train.date.dt.month
train['weekofyear'] = train.date.dt.weekofyear
train['yearmonth'] = train['date'].apply(lambda x: '{}-{:02d}'.format(x.year, x.month))
train['weekday'] = train['date'].dt.weekday
# Out:
# C:\Users\Rachel\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   import sys

# %%
# drop the redundant location columns since we have `latitude` and `longitude`
train.drop(columns=['address', 'block', 'street', 'addressnumberandstreet', 'addressaccuracy'], inplace=True)

# %% [markdown]
# No imputation is required for the train dataset.

# %% [markdown]
# ---

# %% [markdown]
# ### Data Cleaning - Weather

# %%
# Import weather dataset
weather = pd.read_csv('https://raw.githubusercontent.com/zixinlee/GA-data-science/master/West-nile-virus/data/weather.csv')

# %%
# Call EDA function
basic_eda(weather, df_name='weather.csv DETAILS')
# Out:
# WEATHER.CSV DETAILS
# **********************************************
# Rows: 2944 	 Columns: 22
# ...
#
# weather.csv DETAILS.info()
# ----------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   object
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2944 non-null   object
#  5   Depart       2944 non-null   object
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2944 non-null   object
#  8   Heat         2944 non-null   object
#  9   Cool         2944 non-null   object
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        2944 non-null   object
# ...

# %% [markdown]
# **Observations**
# * 22 features
# * 2944 observations
# * 6 numerical data (Station Tmax, Tmin, Dewpoint, ResultSpeed, ResultDir)
# * 16 object data
# * initial check all object type should be numerical. TO investigate further
# * To change date column to datetime type
# * no Null values observed.
# * no duplicated rows
# * All empty values are filled with ``'M'`` or ``'-'``. To convert and check

# %% [markdown]
# ---

# %% [markdown]
# We will proceed by:
#  - Changing all column names to lower case
#  - Converting the 'date' column to datetime format
#  - Imputing missing values
#  - Converting 'depart' and 'wetbulb' columns to numeric

# %%
# make all column names lowercase
weather.columns = weather.columns.str.lower()

# %%
# convert `date` to datetime datatype
weather['date'] = pd.to_datetime(weather['date'])

# %%
# use values from the other station to impute missing values for `depart`, `wetbulb`, `avgspeed`, and `preciptotal`
for feature in ['depart', 'wetbulb', 'avgspeed', 'preciptotal']:
    for k,v in enumerate(weather[feature]):
        if v == 'M' and weather.loc[k, 'station'] == 1:
            weather.loc[k, feature] = weather.loc[k+1, feature]
        if v == 'M' and weather.loc[k, 'station'] == 2:
            weather.loc[k, feature] = weather.loc[k-1, feature]

# %%
(weather[weather['tavg'] != 'M']['tavg'].astype('float') - \
 ((weather[weather['tavg'] != 'M']['tmax'] + weather[weather['tavg'] != 'M']['tmin'])/2)).mean()
# Out:
# 0.25196045005114215

# %% [markdown]
# As the average difference between the mean of `tmax` and `tmin` vs `tavg` is low (0.25), we will replace 'tavg' with this value.

# %%
# there are missing values in `tavg` so we will use `tmin` and `tmax` to calculate average temp
weather['tavg'] = (weather.tmin + weather.tmax) / 2

# %%
# replace trace amounts of precipitation(https://www.thoughtco.com/what-is-trace-of-precipitation-3444238) with 0.001
weather['preciptotal'] = np.where(weather['preciptotal'] == '  T', '0.001', weather['preciptotal'])

# %%
# Impute missing values for `sunrise` and `sunset`

# Fill missing `sunrise` and `sunset` values in station 2 from station 1
for feature in ['sunrise', 'sunset']:
    for k, v in enumerate(weather[feature]):
        if v == '-' and weather.loc[k, 'station'] == 2:
            weather.loc[k, feature] = weather.loc[k-1, feature]

# there are 3 incorrect timestamp values in `sunset`
# replace all the wrong timestamp with the correct values
weather['sunset'] = np.where(weather['sunset'] == '1860', '1900', weather['sunset'])
weather['sunset'] = np.where(weather['sunset'] == '1760', '1800', weather['sunset'])
weather['sunset'] = np.where(weather['sunset'] == '1660', '1700', weather['sunset'])

# convert `sunset` to datetime format
weather['sunset'] = pd.to_datetime(weather['sunset'].apply(lambda x: x[:2] + ':' + x[2:] + ':00')).dt.time

# convert `sunrise` to datetime format
weather['sunrise'] = pd.to_datetime(weather['sunrise'].apply(lambda x: x[:2] + ':' + x[2:] + ':00')).dt.time

# %%
# converting `depart`, `wetbulb`, `preciptotal` and `avgspeed` into numeric
weather['depart'] = pd.to_numeric(weather['depart'], errors='coerce')
weather['wetbulb'] = pd.to_numeric(weather['wetbulb'], errors='coerce')
weather['preciptotal'] = pd.to_numeric(weather['preciptotal'], errors='coerce')
weather['avgspeed'] = pd.to_numeric(weather['avgspeed'], errors='coerce')

# %% [markdown]
# **Drop redundant columns**
#
# (explanation incomplete – feel free to add)
# - Drop `codesum` since most of the values are either missing or rain(RA) / mist(BR)
# - Drop `depth` because we are missing all our values and it is related to snowfall
# - Drop `water1` since 100% of values are missing
# - Drop `snowfall` since 50% of values are missing and almost 50% of values are 0. The WNV only occurs during summer months so `snowfall` is likely not a relevant variable as well.
# - Drop `stnpressure` - no relevance to our project
# - Drop `sealevel` - no relevance to our project
# - Drop `heat` ,  `cool`
# Degree days are the difference between the daily temperature mean, (high temperature plus low temperature divided by two) and 65°F. If the temperature mean is above 65°F, we subtract 65 from the mean and the result is Cooling Degree Days. Degree days (in this context) are based on the assumption that when the outside temperature is 65°F, we don't need heating or cooling to be comfortable. THis is typically used for energy consumption (https://www.weather.gov/key/climate_heat_cool).
# IN this instance Heat, Cool are not relevant in our findings, hence will drop both columns

# %%
cols_to_drop = ['codesum', 'depth', 'water1', 'snowfall', 'stnpressure', 'heat', 'cool']
weather.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Data Cleaning - Spray

# %%
# Import spray dataset
spray = pd.read_csv('https://raw.githubusercontent.com/zixinlee/GA-data-science/master/West-nile-virus/data/spray.csv')

# %%
# Call EDA function
basic_eda(spray, df_name='spray.csv DETAILS')
# Out:
# SPRAY.CSV DETAILS
# **********************************************
# Rows: 14835 	 Columns: 4
# ...
#
# spray.csv DETAILS.info()
# ----------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14835 non-null  object
#  1   Time       14251 non-null  object
#  2   Latitude   14835 non-null  float64
#  3   Longitude  14835 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 463.7+ KB
# None
# ...
# spray.csv DETAILS.null()
# ----------------------------------------------
# Date           0
# Time         584
# Latitude       0
# Longitude      0
# dtype: int64
# ...
# Total null rows: 584
# Percentage null rows: 3.94%
#
# Total duplicate rows: 543
# Percentage dupe rows: 3.66%
#
# **********************************************

# %% [markdown]
# **Observations**
# - 4 features
# - 14835 observations, out of which 584 are null from the Time column
# - Date and Time columns to be changed to DateTime Objects

# %%
spray[spray['Time'].isnull()]['Date'].unique()
# Out:
# array(['2011-09-07'], dtype=object)

# %% [markdown]
# Although the % of rows that are null consist of only 3.94% of the dataset, the data is not missing at completely random as the missing values are all from the same day. Though we may not eventually use this feature, we will first impute with the mode.

# %%
spray['Time'].value_counts(ascending = False)
# Out:
# 7:44:32 PM     541
# 9:38:27 PM       5
# 8:55:26 PM       5
# 8:55:36 PM       5
# 9:35:47 PM       5
#               ...
# 11:18:21 PM      1
# 9:33:49 PM       1
# 9:45:26 PM       1
# 8:37:11 PM       1
# 8:46:07 PM       1
# Name: Time, Length: 8583, dtype: int64

# %%
spray[spray['Time'] == '7:44:32 PM']['Date'].unique()
# Out:
# array(['2011-09-07'], dtype=object)

# %% [markdown]
# It appears that there are some errors relating to the `Time` feature on 7th September 2011.

# %%
# Impute with the mode
spray['Time'] = spray['Time'].replace(np.nan, spray['Time'].value_counts(ascending = False).index[0])

# %%
# make all column names lowercase
spray.columns = spray.columns.str.lower()

# %%
# convert `date` and `time` to datetime datatype
spray['date'] = pd.to_datetime(spray['date'])
spray['time'] = pd.to_datetime(spray['time'])

# %% [markdown]
# ---

# %% [markdown]
# ## EDA

# %% [markdown]
# ### EDA - Train
#
#
# - Range from May 2007 to Sep 2013
# - Data only available for 2007, 2009, 2011 and 2013

# %%
train['wnvpresent'].value_counts(normalize=True)
# Out:
# 0   0.948
# 1   0.052
# Name: wnvpresent, dtype: float64

# %% [markdown]
# This dataset has significant imbalance between classes.

# %% [markdown]
# #### Total Sample records across Year, Month

# %%
ax = pd.DataFrame(train.groupby([train['year'], train['month']]).count()['date']).plot(kind='bar', figsize=(10,5))
ax.set_xlabel('(year, month)')
ax.set_title('No. of samples done in a given (year, month)');

# %% [markdown]
# It is observed that there is a significant spike in the number of samples taken in August 2007.
#
# It is also observed that there were more samples taken in the months from June to August.

# %% [markdown]
# #### Samples with WNV present across Year, Month

# %%
ax = pd.DataFrame(train.groupby([train['year'], train['month']]).sum()['wnvpresent']).plot(kind='bar', figsize=(10,5))
ax.set_xlabel('(year, month)')
ax.set_title('No. of samples with Wnv found in a given (year, month)');

# %% [markdown]
# There are significant spikes in WNV detections in August 2007 and August 2013.

# %% [markdown]
# #### Total number of Mosquitos collected across Year, Month

# %%
# See the number toal number samples across months
ax = pd.DataFrame(train.groupby([train['year'], train['month']]).sum()['nummosquitos']).plot(kind='bar', figsize=(10,5))
ax.set_xlabel('(year, month)')
ax.set_title('No. of Mosquitos trapped in a given (year, month)');

# %% [markdown]
# It is observed that there were significantly more mosquitos tested in August 2007 than in any other month.

# %% [markdown]
# #### Mosquito Species spread

# %%
train['species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    4752
# CULEX RESTUANS            2740
# CULEX PIPIENS             2699
# CULEX TERRITANS            222
# CULEX SALINARIUS            86
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# Name: species, dtype: int64

# %%
plt.figure(figsize = (10,6))
species_counts = (train.groupby(['wnvpresent'])['species']
                  .value_counts(normalize=True)
                  .rename('percentage count of mosquitos')
                  .mul(100)
                  .reset_index()
                  .sort_values('species'))
p = sns.barplot(x="species", y="percentage count of mosquitos", 
                hue="wnvpresent", data=species_counts, 
                order = train['species'].value_counts().index)

_ = plt.setp(p.get_xticklabels(), rotation=45)
plt.legend(loc='upper right');
p.set_title('Count of mosquitos by species (normalized by class)');

# %%
df_MosWnv = pd.DataFrame(train[['species', 'nummosquitos', 'wnvpresent']].groupby(by='species').sum())
df_MosWnv
# Out:
#                         nummosquitos  wnvpresent
# species
# CULEX ERRATICUS                    7           0
# CULEX PIPIENS                  44671         240
# CULEX PIPIENS/RESTUANS         66268         262
# CULEX RESTUANS                 23431          49
# CULEX SALINARIUS                 145           0
# CULEX TARSALIS                     7           0
# CULEX TERRITANS                  510           0

# %% [markdown]
# It is appears that the virus has only been observed in 3 species:
#  - Culex Pipiens
#  - Culex Pipiens/Restuans
#  - Culex Restuans

# %% [markdown]
# #### No of Traps and Wnv present

# %%
train['trap'].nunique()
# Out:
# 136

# %%
train[train['wnvpresent'] == 1]['trap'].nunique()
# Out:
# 97

# %% [markdown]
# There are a total of 136 traps, of which the west nile virus has been observed in 97.

# %% [markdown]
# #### Visualizing Location of Traps and presence of Wnv

# %%
mapdata = np.loadtxt('https://raw.githubusercontent.com/rachellimce/DSI_Projects/master/project_4/datasets/mapdata_copyright_openstreetmap_contributors.txt')
aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88, -87.5, 41.6, 42.1)

# create plot for each month and year 
#loop year
for year in train['date'].dt.year.unique():
    fig, ax = plt.subplots(ncols = 6, figsize = (16,5))
    
    #loop month
    for i, month in enumerate(train['date'].dt.month.unique()):
        # plot basemap
        ax[i].imshow(mapdata, cmap=plt.get_cmap('gray'), extent=lon_lat_box, aspect=aspect)
        
        ## plot station locations
        station = np.array([[-87.933, 41.995], [-87.752, 41.786]])
        ax[i].scatter(station[:,0], station[:,1], marker='o', c = 'blue', s=70, alpha = 0.7)
        
        # plot trap locations
        locations = train[['longitude', 'latitude']].drop_duplicates().values
        ax[i].scatter(locations[:,0], locations[:,1], marker='x', c = 'black', s=50, alpha = 0.7)
        
        # plot wnv locations
        wnv = train[(train['date'].dt.year == year) & (train['date'].dt.month == month) & (train['wnvpresent'] == 1)]\
                [['longitude', 'latitude']].drop_duplicates().values
        
        ax[i].scatter(wnv[:,0], wnv[:,1], marker='o', c = 'orange', s =20)
        
        # title and axes
        ax[i].set_title(f"{year}-{month}", fontsize = 15, ha = 'left', position = (0,1))
        ax[i].set_xticks([])
        ax[i].set_yticks([])
        
        plt.tight_layout()
#         plt.savefig(f'heatmap_{year}_{month}')


plt.legend(loc='lower right', fontsize=14)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
df_TrapMosWnv = pd.DataFrame(train[['trap', 'nummosquitos', 'wnvpresent']].groupby(by='trap').sum().sort_values(by='wnvpresent', ascending=False))

#show the top 10 traps that had the most number of wnv cases detected
df_TrapMosWnv.head(10)
# Out:
#       nummosquitos  wnvpresent
# trap
# T900         15386          66
# T115         21668          41
# T002          3710          18
# T138          9936          16
# T003          1346          14
# T011          1311          11
# T225          2014          11
# T128          3315          11
# T903          2327          10
# T008          2668          10

# %% [markdown]
# It is observed that:
# <li>T900 has the highest number of total mosquitos trapped and highest number of Wnv detected, followed by T115.
# <li>There were much fewer mosquitos collected at T002 (62% fewer) as compared to T138 but higher occurance of wnv.
# <li>There were only 1346 mosquitos collected at T003, but there were as many as 14 virus occurances observed.
# <li>We investigate these top 5 locations for further analysis.

# %% [markdown]
# # <font color=blue> David: Not sure if plot directly below is needed

# %%
sns.lmplot(x='wnvpresent', y='nummosquitos', data=df_TrapMosWnv)

# %%
lst_traps = ['T900', 'T115', 'T002', 'T138', 'T003']

for year in train['date'].dt.year.unique():
    fig, ax = plt.subplots(ncols = 6, figsize = (16,5))
    
    #loop month
    for i, month in enumerate(train['date'].dt.month.unique()):
        # plot basemap
        ax[i].imshow(mapdata, cmap=plt.get_cmap('gray'), extent=lon_lat_box, aspect=aspect)
        
        ## plot station locations
        station = np.array([[-87.933, 41.995], [-87.752, 41.786]])
        ax[i].scatter(station[:,0], station[:,1], marker='o', c = 'blue', s=70, alpha = 0.7)
        
        # plot trap locations
        locations = train[train['trap'].isin(lst_traps)][['longitude', 'latitude']].drop_duplicates().values
        ax[i].scatter(locations[:,0], locations[:,1], marker='s', c = 'yellow', s=70, alpha = 0.7)
        
        # plot wnv locations
        wnv = train[(train['trap'].isin(lst_traps)) & (train['date'].dt.year == year) & (train['date'].dt.month == month) & (train['wnvpresent'] == 1)]\
                [['longitude', 'latitude']].drop_duplicates().values
        
        ax[i].scatter(wnv[:,0], wnv[:,1], marker='s', c = 'crimson', s =80)
        
        # title and axes
        ax[i].set_title(f"{year}-{month}", fontsize = 15, ha = 'left', position = (0,1))
        ax[i].set_xticks([])
        ax[i].set_yticks([])
        
        plt.tight_layout()
#         plt.savefig(f'heatmap_{year}_{month}')


plt.legend(loc='lower right', fontsize=14)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We see that all observed occurences of this virus in these five traps happen between the months of July and September.

# %%
lst_traps = ['T900', 'T115', 'T002', 'T138', 'T003']
df_selectedtraps = train[train['trap'].isin(lst_traps)]
df_selectedtraps = pd.DataFrame(df_selectedtraps[['yearmonth', 'trap','nummosquitos']].groupby(by=['yearmonth', 'trap']).sum()).sort_values(by='yearmonth')

# %% [markdown]
# # <font color=blue> David: Can't figure out why plot below is in the wrong order 😵

# %%
# since temp_df now is a multi-index df, we need to iterate through the index to pass `YearMonth` and `Species` to the plot  function
x_index = [keys for keys, values in df_selectedtraps.index]
hue_index = [values for keys, values in df_selectedtraps.index]

plt.figure(figsize=(18,12))

sns.lineplot(x = x_index, y = "nummosquitos", data = df_selectedtraps, hue = hue_index, sort = True)

plt.xlabel('Year-Month', fontweight='bold', fontsize='20', horizontalalignment='center')
plt.ylabel('Number of Mosquitoes', fontweight='bold', fontsize='20', horizontalalignment='center')

plt.tick_params(axis='both', which='major', labelsize=15)
plt.xticks(rotation=45)

title = "Total mosquito count by Year-Month (by Trap)"
plt.suptitle(title, fontweight='bold', fontsize='20', horizontalalignment='center')

plt.legend(fontsize='large', title_fontsize='20')


plt.tight_layout()

plt.savefig(title)

# %% [markdown]
# #### Counting total Mosquito in a Trap
#
# As the test results are organized in a way that the number of mosquitoes are capped at 50 for each record even when the samples are collected on the same day. We will combine these records into a single record, track the total number of mosquito collected, and how many records were collected.

# %%
total_mosq = train[['date', 'species', 'trap', 'nummosquitos', 'wnvpresent']]\
    .groupby(['date', 'species', 'trap'])\
        .agg(row_count=('trap', 'count'),
             mosquito_count=('nummosquitos', 'sum'), 
             wnv_count=('wnvpresent', 'sum')).reset_index().sort_values('row_count')

total_mosq['wnvpresent'] = total_mosq['wnv_count'].map(lambda x : 1 if x > 0 else x)

# %%
total_mosq.shape
# Out:
# (8475, 7)

# %%
total_mosq.sort_values(by='wnv_count', ascending=False)
# Out:
#            date                 species  trap  row_count  mosquito_count  \
# 1450 2007-08-16           CULEX PIPIENS  T115         51            2532
# 7428 2013-08-01  CULEX PIPIENS/RESTUANS  T900         25             984
# 7971 2013-08-29           CULEX PIPIENS  T900         10             281
# 1666 2007-08-22           CULEX PIPIENS  T115         32            1554
# 1669 2007-08-22           CULEX PIPIENS  T138         22            1054
# ...         ...                     ...   ...        ...             ...
# 7957 2013-08-29           CULEX PIPIENS  T138          1               9
# 7958 2013-08-29           CULEX PIPIENS  T145          1              13
# 7959 2013-08-29           CULEX PIPIENS  T151          1              17
# 7996 2013-08-29  CULEX PIPIENS/RESTUANS  T074          1               8
# 1742 2007-08-24           CULEX PIPIENS  T047          1              15
#
#       wnv_count  wnvpresent
# 1450         10           1
# 7428          9           1
# ...

# %%
sns.pairplot(total_mosq)

# %% [markdown]
# As expected, there is a very strong positive linear relationship between `row_count` and `mosquito_count`. This may be useful for feature engineering if the `nummosquitos` feature is not present.

# %% [markdown]
# ---

# %% [markdown]
# ### EDA - Weather
#
# - Range from May 2007 to Oct 2014
# - Data is collected from 2 different stations

# %% [markdown]
# #### Average Temperature Across Year

# %%
plt.figure(figsize=(18,8))
sns.lineplot(x = weather['date'].dt.month, y = 'tavg', data = weather, 
             hue = weather['date'].dt.year, ci = None, 
             legend = 'full', palette = 'Spectral')
plt.legend(fontsize = 14)
plt.title('Monthly mean temperatures (F)', fontsize=16)
plt.xlabel('Month',fontsize=14)
plt.ylabel('Mean temperature (F)',fontsize=14)
plt.xlim(weather['date'].dt.month.unique().min(), weather['date'].dt.month.unique().max())
# Out:
# (5.0, 10.0)

# %% [markdown]
# Temperature shows similar trends of reaching the highest (to about 70 F) in Aug every year except for 2010 to 2012, where the temperature peaks at July instead.
# We also see a climb in Mosquito collection and Wnv detection during July/Aug months for 2007 and 2013

# %% [markdown]
# #### Average Rainfall Across Year

# %%
plt.figure(figsize=(18,8))
sns.lineplot(x = weather['date'].dt.month, y = 'preciptotal', data = weather, 
             hue = weather['date'].dt.year, ci = None, 
             legend = 'full', palette = 'Spectral')
plt.legend(fontsize = 14)
plt.title('Monthly mean Rainfall (inches & hundredths)', fontsize=16)
plt.xlabel('Month',fontsize=14)
plt.ylabel('Mean Rainfall',fontsize=14)
plt.xlim(weather['date'].dt.month.unique().min(), weather['date'].dt.month.unique().max())
# Out:
# (5.0, 10.0)

# %% [markdown]
# No specific pattern in the average amount of rainfall as it varies from year to year. 2007 has a higher rainfall in Aug (which has higher Wnv detection rate), but we don't see the same trend for 2013
# There is also higher than normal amounts of rain in Sept 2009.

# %% [markdown]
# #### Average Relative Humidity Across Year

# %%
plt.figure(figsize=(18,8))
sns.lineplot(x = weather['date'].dt.month, y = 'rhumidity', data = weather, 
             hue = weather['date'].dt.year, ci = None, 
             legend = 'full', palette = 'Spectral')
plt.legend(fontsize = 14)
plt.title('Monthly mean Relative Humidity (%)', fontsize=16)
plt.xlabel('Month',fontsize=14)
plt.ylabel('Mean RH',fontsize=14)
plt.xlim(weather['date'].dt.month.unique().min(), weather['date'].dt.month.unique().max())
# Out:
# (5.0, 10.0)

# %% [markdown]
# ### EDA - Spray data
#
# - Range from Aug 2011 to Sep 2013
# - There is no data for 2008 to 2010 and no data for 2012, 2014.
#
# Since there is no spray data for 2008 to 2010 and no data for 2012, 2014, we are not able to use data from this set as features to predict for 2008, 2010, 2012 and 2014 data. We will ignore spray data for now

# %% [markdown]
# ## Feature Engineering
# ---

# %% [markdown]
# ### Feature Engineering - Train
#
# - ```closest_station``` - the closest weather station to observed `trap`.
#     - Will be used to join `train` and `weather` datasets.
# - `species` Consolidation - Consolidate all species not observed to carry virus into `others` category.

# %% [markdown]
# #### Feature Consolidation: ```species```
#
# For species that are not observed to have the west nile virus, group into new category 'other'.

# %%
train[train['wnvpresent'] == 1]['species'].unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX PIPIENS', 'CULEX RESTUANS'],
#       dtype=object)

# %% [markdown]
# Only 'CULEX PIPIENS' and 'CULEX RESTUANS' have observations at which the west nile virus is present, therefore we will group all other species into new category: 'other'.

# %%
# list of species observed to have west nile virus
virusobserved = list(train[train['wnvpresent'] == 1]['species'].unique())
# replace selected species with `OTHER`
train['species'] = train['species'].apply(lambda x: 'OTHER' if x not in virusobserved else x)

# %% [markdown]
# #### New Feature: ```closest_station```
#
# For each trap, identify the closer weather station and create a column to store the results
#
# - Station 1: CHICAGO O'HARE INTERNATIONAL AIRPORT Lat: 41.995 Lon: -87.933 Elev: 662 ft. above sea level
#
# - Station 2: CHICAGO MIDWAY INTL ARPT Lat: 41.786 Lon: -87.752 Elev: 612 ft. above sea level

# %%
# Zip latitude and longitude together for efficient iteration
train['coords'] = list(zip(train['latitude'], train['longitude']))

# create function to find the closer weather station from each trap
def closest_dist(coords):
    coords_s1 = (41.995, -87.933) # coordinates of station 1
    coords_s2 = (41.786, -87.752) # coordinates of station 2
    dist_from_s1 = geopy.distance.distance(coords_s1, coords).km
    dist_from_s2 = geopy.distance.distance(coords_s2, coords).km
    if dist_from_s1 > dist_from_s2:
        return 2
    else:
        return 1

# apply the function and create the `closest_station` column
train['closest_station'] = train['coords'].apply(closest_dist)

# delete the `coords` column
train.drop(columns='coords', inplace=True)

# %% [markdown]
# #### New Feature: ```row_count```
#
# For each observation, count the number of "duplicate" rows in order to get an estimate for `nummosquitos`.

# %%
row_count = train[['date', 'species', 'trap', 'nummosquitos']]\
                .groupby(['date', 'species', 'trap'])\
                    .agg(row_count=('species', 'count')).reset_index().sort_values('row_count')

train = train.merge(row_count, how='left', on=['date', 'species', 'trap'])

# %% [markdown]
# #### New Feature: `intensity_acc`
#
# `intensity_acc` calculates the "intensity" for each observation in the train dataset.
#
# The intensity is calculated by summing up every `spray` observation that occurs before the `train` observation. These values are scaled by 1/days and 1/sqrt(dist).

# %% [markdown]
# ```# combines latitude and longitude for ease of iteration
# train['coords'] = list(zip(train['latitude'], train['longitude']))
# spray['coords'] = list(zip(spray['latitude'], spray['longitude']))
#
# # converts date into numerical for more efficient date comparison
# train['tempdate'] = train['date'].astype('str').str.replace('-','').astype('int64')
# spray['tempdate'] = spray['date'].astype('str').str.replace('-','').astype('int64')
#
# # create `spray_set` dictionary for faster iteration
# spray_set = {}
# for i in spray['tempdate'].unique():
#     spray_set[i]=[j for j in spray[spray['tempdate'] == i]['coords']]
#
# # initialize starttime for estimate of runtime
# starttime = time.time()
#
# # create a zip instance of date and coordinates for faster iteration
# date_list = [i for i in train['tempdate']]
# latlong_list = [i for i in train['coords']]
# zipped = zip(date_list, latlong_list)
#
# # initialize empty `intensity_acc`
# intensity_acc = []
#
#
# for index, i in enumerate(zipped):
#
#     # print % completed
#     print(f"{round(100*index/len(date_list), 2)}% Complete")
#
#     # print estimated time remaining if index not 0 to avoid zero division error
#     if index != 0:
#         print(f"Estimated time remaining: {(len(date_list)-index)*((time.time()-starttime)/index)/60} minutes")
#
#     # reset `intensity_cache`
#     intensity_cache = 0
#
#     # iterate over all values in `spray_set`
#     for j in spray_set:
#         dist = 0
#         intensity = 0.0
#         days = (i[0] - j) + 1
#
#         # if days between train and spray are greater than 0, iterate over `spray_set`
#         if days > 0:
#             for k in spray_set[j]:
#                 dist = geopy.distance.distance(i[1], k).m
#
#                 # https://en.wikipedia.org/wiki/Inverse-square_law
#                 intensity = 1/np.sqrt(dist)
#             days = 1/days
#             intensity = intensity * days
#             intensity_cache += intensity
#
#     intensity_acc.append(intensity_cache)
#
# print(f"{(time.time() - starttime)/60} minutes elapsed.")
# train['intensity_acc'] = pd.Series(intensity_acc)
# train.head(2)
#
# # drop redundant columns
# train.drop(columns=['coords', 'tempdate'], inplace=True)
# spray.drop(columns=['coords', 'tempdate'], inplace=True)```

# %% [markdown]
# ### Feature Engineering - Weather
#
# - ```daytime``` - the total number of minutes from ``Sunrise`` to ``Sunset``
# - ``rhumidity`` - the relative humidity based on ``dewpoint`` and ``tavg``
# - Rolling averages for 7, 10, 14, 30, 60, 90 days. Columns applied: `tavg`, `resultspeed`, `dewpoint`, `rhumidity`, `tmax`, `tmin`, `preciptotal`, and `rhumidity`.
# - Joining `weather` dataset to `train` dataset by `date` and `station`.

# %% [markdown]
# #### New Feature: ```daytime```

# %%
# create a `daytime` column
weather['daytime'] = pd.to_timedelta(weather['sunset'].astype(str)) - pd.to_timedelta(weather['sunrise'].astype(str))

# convert `daytime` to minutes
weather['daytime'] = weather['daytime'].dt.total_seconds().div(60).astype(int)

# %% [markdown]
# #### New Feature: ```rhumidity```
# Since relative humidity is a factor of mosquito growth, we create a column ```rhumidity``` using formula:
# > ```100*(np.exp((17.625*dewpoint)/(243.04+dewpoint))/np.exp((17.625*Temp)/(243.04+Temp)))```

# %%
#To Create a new column 'rhumidity' for relative humidity
#A function to calculate relative humidity
def cal_rH(temp):
    """
    Function converts temp(in deg F to Deg C) to calculate the relatve humidity using formula
    -  100*(np.exp((17.625*dewpoint)/(243.04+dewpoint))/np.exp((17.625*Temp)/(243.04+Temp)))
    
    Reference:
    https://bmcnoldy.rsmas.miami.edu/Humidity.html
    
    Take in arguements:
    - temp - list of dewpoint and avg temp in F
    
    returns:
    - Relative Humidity rH
    """

    #convert dewpoint to Deg C
    TD = (temp[0] - 32) * 5/9
    #convert Tavg to Deg C
    T = (temp[1] - 32) * 5/9

    rH =100*(np.exp((17.625*TD)/(243.04+TD))/np.exp((17.625*T)/(243.04+T)))
    
    return rH

# %%
weather['rH_temp'] = list(zip(weather['dewpoint'], weather['tavg']))

# apply the function and create the `rhumidity` column
weather['rhumidity'] = weather['rH_temp'].apply(cal_rH)

#drop after gotten the relative humidity value
weather.drop(columns='rH_temp', inplace=True)

# %% [markdown]
# # <font color=blue> David: Will need to ammend description below.

# %% [markdown]
# #### New Feature: Rolling averages `tavg`, `resultspeed`, `dewpoint`, `tmax`, `tmin`, `preciptotal`, `rhumidity`
#
# For the Culex pipiens, Cx. quinquefasciatus, and Cx. tarsalis species: the life cycle of the mosquito  - 7-10 days from incubation to adult
# ref: https://www.cdc.gov/westnile/resources/pdfs/FS_MosquitoLifeCycle-508.pdf
#
# We will therefore take rollng 7, 10 and 14 days average for the 3 factors that affect the mosquito breeding:
# - Temperature ```tavg```
# - Precipitation Total ```preciptotal```
# - Relative humidity ```rhumidity```

# %%
for col in ['tavg', 'resultspeed', 'dewpoint', 'rhumidity', 'tmax', 'tmin', 'preciptotal', 'rhumidity']:
    for period in [7, 10, 14, 30, 60, 90]:
        weather[f'{col}_{str(period)}'] = weather[col].rolling(period, min_periods=1).mean()

# %% [markdown]
# #### Feature Consolidation to Train
#
# We will join the `weather` dataset to the `train` dataset using the `date` and `station` columns.

# %%
# Left join `weather` to `train` using `date` and `station` as keys
train_weather = pd.merge(train, weather, left_on=['date', 'closest_station'], right_on=['date', 'station'], how="left")

# %%
train_weather.shape
# Out:
# (10506, 72)

# %%
train_weather.dtypes
# Out:
# date               datetime64[ns]
# species                    object
# trap                       object
# latitude                  float64
# longitude                 float64
# nummosquitos                int64
# wnvpresent                  int64
# year                        int64
# month                       int64
# weekofyear                  int64
# yearmonth                  object
# weekday                     int64
# closest_station             int64
# row_count                   int64
# station                     int64
# tmax                        int64
# tmin                        int64
# tavg                      float64
# depart                      int64
# dewpoint                    int64
# wetbulb                     int64
# sunrise                    object
# sunset                     object
# preciptotal               float64
# sealevel                   object
# resultspeed               float64
# resultdir                   int64
# ...

# %% [markdown]
# #### One Hot Encoding

# %%
train_weather.shape[1] + train_weather['species'].nunique() + train_weather['trap'].nunique()
# Out:
# 212

# %%
# create dummy variables for `species` and `trap`
train_dum = pd.get_dummies(data=train_weather, columns=['species', 'trap'])

# %%
train_dum.shape
# Out:
# (10506, 210)

# %%
train_dum.dtypes
# Out:
# date                              datetime64[ns]
# latitude                                 float64
# longitude                                float64
# nummosquitos                               int64
# wnvpresent                                 int64
# year                                       int64
# month                                      int64
# weekofyear                                 int64
# yearmonth                                 object
# weekday                                    int64
# closest_station                            int64
# row_count                                  int64
# station                                    int64
# tmax                                       int64
# tmin                                       int64
# tavg                                     float64
# depart                                     int64
# dewpoint                                   int64
# wetbulb                                    int64
# ...

# %% [markdown]
# ## Modelling
#
# ### Oversampling to tackle imbalanced classes
#
# Due to the highly imbalanced dataset, we will oversample the minority class (WNV not present) via the SMOTE technique prior to modelling.
#
# SMOTE works by selecting examples that are close in the feature space, drawing a line between the examples in the feature space and drawing a new sample at a point along that line.
#
# Specifically, a random example from the minority class is first chosen. Then k of the nearest neighbors for that example are found (typically k=5). A randomly selected neighbor is chosen and a synthetic example is created at a randomly selected point between the two examples in feature space.
#
# ### Evaluation metrics to optimise for
#
# As we want to identify as many of the positive WNV cases as possible, we will optimise for Recall, which is defined as:
#
# Recall = TP / (TP + FN)
#
# If recall = 0.8, it means our model identified 80% of positive samples correctly.
#
#
#
#
# The `grid.best_score_` is the average of all cv folds for a single combination of the parameters you specify in the tuned_params.
#
# ### Baseline score
#
# The baseline score will be an ROC AUC score of 0.5, meaning that the baseline model has no class separation capacity. The model that achieves the highest AUC score on the validation set will be selected as our production model.

# %% [markdown]
# ### Set up X and y

# %%
X = train_dum.drop(columns=['date', 'nummosquitos', 'sealevel', 'yearmonth', 'sunrise', 'sunset', 'station', 'closest_station', 'wnvpresent'])
y = train_dum['wnvpresent']

# %%
X.dtypes
# Out:
# latitude                          float64
# longitude                         float64
# year                                int64
# month                               int64
# weekofyear                          int64
# weekday                             int64
# row_count                           int64
# tmax                                int64
# tmin                                int64
# tavg                              float64
# depart                              int64
# dewpoint                            int64
# wetbulb                             int64
# preciptotal                       float64
# resultspeed                       float64
# resultdir                           int64
# avgspeed                          float64
# daytime                             int32
# rhumidity                         float64
# tavg_7                            float64
# tavg_10                           float64
# tavg_14                           float64
# ...

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, random_state=42, test_size=0.33)

# %%
X_train.shape
# Out:
# (7039, 201)

# %%
y_train.shape
# Out:
# (7039,)

# %%
y_train.value_counts(normalize=True)
# Out:
# 0   0.948
# 1   0.052
# Name: wnvpresent, dtype: float64

# %%
def metrics_for_me(true, pred, prob, cm = False, show_df = False, title = 'Metrics'):
    """
    Function that calculates and returns a dataframe with classification metrics.
    Input
    true: true values of target variable
    pred: predicted values of target variable
    prob: probability of positive class (wnvpresent = 1)
    cm: confusion matrix will be plot if == True
    show_df: dataframe with metrics will be displayed if == True
    title: the column name for the dataframe that is displayed/returned
    Output
    df: dataframe with classification metrics
    Metric Descriptions
    True Positive: Presence of west nile virus correctly predicted
    True Negative: Absence of west nile virus correctly predicted
    False Positives (Type I Error): Absence of virus predicted as presence
    False Negative (Type II Error): Prsence of virus predicted as absence
    Accuracy: Percentage of observations we correctly classified.
    Misclassification Rate: Percentage of observations we incorrectly classified.
    Sensitivity(Recall): Percentage of observations with virus present correctly classified.
    Specificity: Percentage of observations with virus absent correctly classified.
    Precision: Percentage of positive virus predictions vs total positive virus predictions
    """
    tn, fp, fn, tp = confusion_matrix(true, pred).ravel()
    if cm:
        sns.set(color_codes=True)
        plt.figure(1, figsize=(10, 8))
        plt.title("Confusion Matrix")
        ax = sns.heatmap([[tn,fp],[fn,tp]], 
                         annot=True, 
                         cmap="YlGnBu", 
                         cbar_kws={'label': 'Scale'}, 
                         fmt='g')
        ax.set_xticklabels(['Virus Absent', 'Virus Present'])
        ax.set_yticklabels(['Virus Absent', 'Virus Present'])
        ax.set(ylabel="True Label", xlabel="Predicted Label")
    df = pd.DataFrame(data = [(tp+tn)/(tp+fp+tn+fn),
                              1- ((tp+tn)/(tp+fp+tn+fn)),
                              tp/(tp+fn),
                              tn/(tn+fp),
                              tp/(tp+fp),
                              tp,
                              fp,
                              fn,
                              tn,
                              roc_auc_score(true,prob)],
                         index = ['Accuracy',
                                  'Misclassification Rate',
                                  'Sensitivity(Recall)',
                                  'Specificity',
                                  'Precision', 
                                  'True Positive',
                                  'False Positive',
                                  'False Negative',
                                  'True Negative', 
                                  'ROC Score'],
                        columns = [title])
    if show_df:
        display(df)
    return(df)

# %% [markdown]
# ### Logistic regression
#
# Logistic regression is one of the most commonly used methods for binary classification problems. We will apply logistic regression here to predict the probability of WNV presence.

# %%
lr = LogisticRegression()

# %%
lr.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
# set up pipeline
pipe_lr = Pipeline([('sc', StandardScaler()), 
                 ('sm', SMOTE(random_state = 42)), 
                 ('lr', LogisticRegression(random_state = 42, solver='liblinear'))])

# hyperparameters for gridsearch
pipe_lr_params = {
#                 'sm__k_neighbors': [5,6],
                  'lr__penalty': ['l1', 'l2'],
                  'lr__C': [0.001, .01, .1, 1]
}

# instantiate GridSearchCV
gs_lr = GridSearchCV(pipe_lr,
                     param_grid = pipe_lr_params,
                     cv=10,
                     scoring='roc_auc')

# fit model on training data
gs_lr.fit(X_train, y_train)

# generate predictions on validation set
lr_pred = gs_lr.predict(X_val)

# print results
print('Best parameters: ', gs_lr.best_params_)
print('Best CV AUC score: ', gs_lr.best_score_)
print('Training AUC score:', gs_lr.score(X_train, y_train))
print('Validation AUC score:', gs_lr.score(X_val, y_val))
print()
# Out:
# Best parameters:  {'lr__C': 0.01, 'lr__penalty': 'l1'}
# Best CV AUC score:  0.8145883702292999
# Training AUC score: 0.850793302535724
# Validation AUC score: 0.7975964674594812

# %%
lr_m = metrics_for_me(y_val, lr_pred, [i[1] for i in gs_lr.predict_proba(X_val)], title="lr")
lr_m
# Out:
#                               lr
# Accuracy                   0.731
# Misclassification Rate     0.269
# Sensitivity(Recall)        0.731
# Specificity                0.731
# Precision                  0.131
# True Positive            133.000
# False Positive           885.000
# False Negative            49.000
# True Negative          2,400.000
# ROC Score                  0.798

# %% [markdown]
# ### Support Vector Machine

# %%
svm = SVC(probability=True)

# %%
svm.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
pipe_svm = Pipeline([('sc', StandardScaler()),
                     ('sm', SMOTE(random_state = 42)), 
                     ('svm', SVC(probability=True))])

# hyperparameters for gridsearch
pipe_svm_params = {
    'svm__C': [1.0, 2.0, 3.0],
    'svm__kernel': ['rbf', 'linear', 'poly'],
    'svm__degree': [3,4,5]
}

# instantiate GridSearchCV
gs_svm = GridSearchCV(pipe_svm,
                      param_grid=pipe_svm_params,
                      cv=10,
                      scoring='roc_auc')

# fit model on training data
gs_svm.fit(X_train, y_train)

# generate predictions on validation set
svm_pred = gs_svm.predict(X_val)

# print results
print('Best parameters: ', gs_svm.best_params_)
print('Best CV AUC score: ', gs_svm.best_score_)
print('Training AUC score:', gs_svm.score(X_train, y_train))
print('Validation AUC score:', gs_svm.score(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-3affbe860306> in <module>
#      17
#      18 # fit model on training data
# ---> 19 gs_svm.fit(X_train, y_train)
#      20
#      21 # generate predictions on validation set
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...

# %%
svm_m = metrics_for_me(y_val, svm_pred, [i[1] for i in gs_svm.predict_proba(X_val)], title='svm')
svm_m

# %% [markdown]
# ### Bagging Classifier
#
# Decision trees are prone to overfitting, so we will mitigate this problem by using bagged decision trees.
#
# Bagging (bootstrap aggregating) mitigates this problem by exposing different trees to different sub-samples of the training set.
#
#
# You can use bagging with any type of classifier. However, because bagging is an ensemble method, and logistic regression is a stable classifier, they are not a powerful combo. On the other hand, decision trees are unstable classifiers and they work well when combined in ensembles. The reason for this is that in order for your ensemble to work well, the classifiers in the ensemble should produce independent mistakes. Unstable classifiers, such as decision trees, tend to perform significantly different when the training set is slightly perturbed. This is why the ensemble methods use bootstrap sampling to create a separate training set for all classifiers in the ensemble.

# %%
# set up pipeline
pipe_bag = Pipeline([('sm', SMOTE(random_state = 42)), 
                     ('bag', BaggingClassifier(base_estimator=DecisionTreeClassifier(), random_state = 42))])

# hyperparameters for gridsearch
pipe_bag_params = {
    'bag__n_estimators' : [50, 100, 200],
    'bag__base_estimator__max_depth' : [2,3, 5, 10, 20]
}

# instantiate GridSearchCV
gs_bag = GridSearchCV(pipe_bag,
                      param_grid=pipe_bag_params,
                      cv=10,
                      scoring='roc_auc')

# fit model on training data
gs_bag.fit(X_train, y_train)

# generate predictions on validation set
bag_pred = gs_bag.predict(X_val)

# print results
print('Best parameters: ', gs_bag.best_params_)
print('Best CV AUC score: ', gs_bag.best_score_)
print('Training AUC score:', gs_bag.score(X_train, y_train))
print('Validation AUC score:', gs_bag.score(X_val, y_val))
# Out:
# Best parameters:  {'bag__base_estimator__max_depth': 5, 'bag__n_estimators': 100}
# Best CV AUC score:  0.8200882103993049
# Training AUC score: 0.8600411176525558
# Validation AUC score: 0.7970277819592887

# %%
bag_m = metrics_for_me(y_val, bag_pred, [i[1] for i in gs_bag.predict_proba(X_val)], title='bag')
bag_m
# Out:
#                              bag
# Accuracy                   0.717
# Misclassification Rate     0.283
# Sensitivity(Recall)        0.753
# Specificity                0.715
# Precision                  0.128
# True Positive            137.000
# False Positive           936.000
# False Negative            45.000
# True Negative          2,349.000
# ROC Score                  0.797

# %% [markdown]
# ### Random Forest
#
# With bagged decision trees, we generate many different trees on pretty similar data. These trees are strongly correlated with one another. Because these trees are correlated with one another, they will have high variance.

# %%
# set up pipeline
pipe_rf = Pipeline([('sm', SMOTE(random_state = 42)), 
                    ('rf', RandomForestClassifier(random_state = 42))])


# hyperparameters for gridsearch
pipe_rf_params = {
    'rf__n_estimators': [150, 200, 250],
    'rf__max_depth': [3,5,7,9]
}

# instantiate GridSearchCV
gs_rf = GridSearchCV(pipe_rf,
                      param_grid=pipe_rf_params,
                      cv=10,
                      scoring='roc_auc')

# fit model on training data
gs_rf.fit(X_train, y_train)

# generate predictions on validation set
rf_pred = gs_rf.predict(X_val)

# print results
print('Best parameters: ', gs_rf.best_params_)
print('Best CV AUC score: ', gs_rf.best_score_)
print('Training AUC score:', gs_rf.score(X_train, y_train))
print('Validation AUC score:', gs_rf.score(X_val, y_val))
# Out:
# Best parameters:  {'rf__max_depth': 7, 'rf__n_estimators': 250}
# Best CV AUC score:  0.8396117256686972
# Training AUC score: 0.8848998265095095
# Validation AUC score: 0.8251509525482129

# %%
gs_rf.best_estimator_.steps[1][1]
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=250, random_state=42)

# %%
rf_m = metrics_for_me(y_val, rf_pred, [i[1] for i in gs_rf.predict_proba(X_val)], title='rf')
rf_m
# Out:
#                               rf
# Accuracy                   0.740
# Misclassification Rate     0.260
# Sensitivity(Recall)        0.725
# Specificity                0.741
# Precision                  0.134
# True Positive            132.000
# False Positive           850.000
# False Negative            50.000
# True Negative          2,435.000
# ROC Score                  0.825

# %%
plt.figure(figsize=(10,8))
plt.tick_params(axis='both', labelsize=14)
viz = FeatureImportances(gs_rf.best_estimator_.steps[1][1])
viz.fit(X_train, y_train)
viz.poof();
# Out:
# C:\Users\Rachel\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)

# %% [markdown]
# ### ExtraTrees

# %%
# %%time

# Create a pipeline
# Handle imbalanced class by setting class_weight='balanced' in random forest
pipe_et = Pipeline([('sm', SMOTE(random_state = 42)), 
                    ('et', ExtraTreesClassifier(random_state = 42))])


# hyperparameters for gridsearch
pipe_et_params = {'et__n_estimators': [10, 50, 100, 200],
             'et__max_depth': [2, 4, 6, 8, 10],
             'et__min_samples_leaf': [3, 5, 7, 9],
             'et__class_weight' : ['balanced', 'balanced_subsample'],
            }

# instantiate GridSearchCV
gs_et = GridSearchCV(pipe_rf,
                      param_grid=pipe_rf_params,
                      cv=10,
                      scoring='roc_auc')

# fit model on training data
gs_et.fit(X_train, y_train)

# generate predictions on validation set
et_pred = gs_et.predict(X_val)

# Print best parameters and ROC AUC scores
print('Best parameters: ', gs_et.best_params_)
print('Best CV AUC score: ', gs_et.best_score_)
print('Training AUC score:', gs_et.score(X_train, y_train))
print('Validation AUC score:', gs_et.score(X_val, y_val))
# Out:
# Best parameters:  {'rf__max_depth': 7, 'rf__n_estimators': 250}
# Best CV AUC score:  0.8396117256686972
# Training AUC score: 0.8848998265095095
# Validation AUC score: 0.8251509525482129
# Wall time: 7min 57s

# %%
et_m = metrics_for_me(y_val, et_pred, [i[1] for i in gs_et.predict_proba(X_val)], title='et')
et_m
# Out:
#                               et
# Accuracy                   0.740
# Misclassification Rate     0.260
# Sensitivity(Recall)        0.725
# Specificity                0.741
# Precision                  0.134
# True Positive            132.000
# False Positive           850.000
# False Negative            50.000
# True Negative          2,435.000
# ROC Score                  0.825

# %%
plt.figure(figsize=(10,8))
plt.tick_params(axis='both', labelsize=14)
viz = FeatureImportances(gs_et.best_estimator_.steps[1][1])
viz.fit(X_train, y_train)
viz.poof();
# Out:
# C:\Users\Rachel\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)

# %% [markdown]
# ### AdaBoost

# %%
# Create a pipeline
pipe_ada = Pipeline([('sm', SMOTE(random_state = 42)), 
                     ('ada', AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), random_state = 42))])


# hyperparameters for gridsearch
pipe_ada_params = {
    'ada__learning_rate': [0.9,1], #0.1
    'ada__n_estimators': [50, 100, 200], #150
    'ada__base_estimator__max_depth': [1, 3, 5, 7] #2 
}

# instantiate GridSearchCV
gs_ada = GridSearchCV(pipe_ada,
                          param_grid=pipe_ada_params,
                          cv=10,
                          scoring='roc_auc')

# fit model on training data
gs_ada.fit(X_train, y_train)

# generate predictions on validation set
ada_pred = gs_ada.predict(X_val)

# print results
print('Best parameters: ', gs_ada.best_params_)
print('Best CV AUC score: ', gs_ada.best_score_)
print('Training AUC score:', gs_ada.score(X_train, y_train))
print('Validation AUC score:', gs_ada.score(X_val, y_val))
# Out:
# Best parameters:  {'ada__base_estimator__max_depth': 1, 'ada__learning_rate': 0.9, 'ada__n_estimators': 50}
# Best CV AUC score:  0.8252804341072707
# Training AUC score: 0.85631432251354
# Validation AUC score: 0.80418067472862

# %%
ada_m = metrics_for_me(y_val, ada_pred, [i[1] for i in gs_ada.predict_proba(X_val)], title='ada')
ada_m
# Out:
#                              ada
# Accuracy                   0.794
# Misclassification Rate     0.206
# Sensitivity(Recall)        0.604
# Specificity                0.805
# Precision                  0.146
# True Positive            110.000
# False Positive           641.000
# False Negative            72.000
# True Negative          2,644.000
# ROC Score                  0.804

# %%
plt.figure(figsize=(10,8))
plt.tick_params(axis='both', labelsize=14)
viz = FeatureImportances(gs_ada.best_estimator_.steps[1][1])
viz.fit(X_train, y_train)
viz.poof();
# Out:
# C:\Users\Rachel\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)

# %% [markdown]
# ### Gradient Boosting

# %%
# Create a pipeline
pipe_gb = Pipeline([('sm', SMOTE(random_state=42)),
                     ('gb', GradientBoostingClassifier(random_state=42))])

# hyperparameters for gridsearch
pipe_gb_params = {
    'gb__max_depth': [2, 4, 6, 8], #3
    'gb__n_estimators': [50, 100, 150, 200], #150
    'gb__learning_rate': [0.1, 0.5, 1] 
}

# instantiate GridSearchCV
gs_gb = GridSearchCV(pipe_gb,
                     param_grid= pipe_gb_params,
                     cv=10,
                     scoring='roc_auc')

# fit model on training data
gs_gb.fit(X_train, y_train)

# Generate predictions on validation set
gb_pred = gs_gb.predict(X_val)

# Print best parameters and ROC AUC scores
print('Best parameters: ', gs_gb.best_params_)
print('Best CV AUC score: ', gs_gb.best_score_)
print('Training AUC score:', gs_gb.score(X_train, y_train))
print('Validation AUC score:', gs_gb.score(X_val, y_val))
# Out:
# Best parameters:  {'gb__learning_rate': 0.1, 'gb__max_depth': 2, 'gb__n_estimators': 200}
# Best CV AUC score:  0.8424609204406804
# Training AUC score: 0.8870753647566461
# Validation AUC score: 0.8263911887199558

# %%
gb_m = metrics_for_me(y_val, gb_pred, [i[1] for i in gs_gb.predict_proba(X_val)], title='gb')
gb_m
# Out:
#                               gb
# Accuracy                   0.798
# Misclassification Rate     0.202
# Sensitivity(Recall)        0.648
# Specificity                0.807
# Precision                  0.157
# True Positive            118.000
# False Positive           635.000
# False Negative            64.000
# True Negative          2,650.000
# ROC Score                  0.826

# %%
plt.figure(figsize=(10,8))
plt.tick_params(axis='both', labelsize=14)
viz = FeatureImportances(gs_gb.best_estimator_.steps[1][1])
viz.fit(X_train, y_train)
viz.poof();
# Out:
# C:\Users\Rachel\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)

# %% [markdown]
# ### XGBoost
#
# XGBoost is an implementation of gradient boosted decision trees designed for speed and performance.

# %%
# set up pipeline
pipe_xgb = Pipeline([('sm', SMOTE(random_state = 42)), 
                     ('xgb', XGBClassifier(random_state = 42))])

# hyperparameters for gridsearch
pipe_xgb_params = {
    'xgb__eval_metric' : ['auc'],
    'xgb__subsample' : [0.5], # Randomly sample 0.5 of the data to prevent overfitting
    'xgb__colsample_bytree' : [0.5], 
    'xgb__learning_rate' : [0.1], #0.5
    'xgb__max_depth' : [2, 3, 4], #5
#     'xgb__scale_pos_weight': [7963/441], # Ratio of negative class to positive class
    'xgb__n_estimators' : [100], #500
    'xgb__reg_alpha' : [100], # L1 regularization term on weight #0, 1, 50, 75
    'xgb__reg_lambda' : [100], # L2 regularization term on weights #0, 1, 2, 50,75
    'xgb__gamma' : [0.1], # Gamma specifies the minimum loss reduction required to make a split #.2
    'xgb__objective' : ['binary:logistic']
}


# instantiate GridSearchCV
gs_xgb = GridSearchCV(pipe_xgb,
                      param_grid=pipe_xgb_params,
                      cv=10,
                      scoring='roc_auc')

# fit model on training data
gs_xgb.fit(X_train, y_train)

# generate predictions on validation set
xgb_pred = gs_xgb.predict(X_val)

# print results
print('Best parameters: ', gs_xgb.best_params_)
print('Best CV AUC score: ', gs_xgb.best_score_)
print('Training AUC score:', gs_xgb.score(X_train, y_train))
print('Validation AUC score:', gs_xgb.score(X_val, y_val))
# Out:
# Best parameters:  {'xgb__colsample_bytree': 0.5, 'xgb__eval_metric': 'auc', 'xgb__gamma': 0.1, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 4, 'xgb__n_estimators': 100, 'xgb__objective': 'binary:logistic', 'xgb__reg_alpha': 100, 'xgb__reg_lambda': 100, 'xgb__subsample': 0.5}
# Best CV AUC score:  0.8350558954756856
# Training AUC score: 0.8630193033564519
# Validation AUC score: 0.8260968103433857

# %%
xgb_m = metrics_for_me(y_val, xgb_pred, [i[1] for i in gs_xgb.predict_proba(X_val)], title='xgb')
xgb_m
# Out:
#                              xgb
# Accuracy                   0.755
# Misclassification Rate     0.245
# Sensitivity(Recall)        0.709
# Specificity                0.757
# Precision                  0.139
# True Positive            129.000
# False Positive           798.000
# False Negative            53.000
# True Negative          2,487.000
# ROC Score                  0.826

# %%
plt.figure(figsize=(10,8))
plt.tick_params(axis='both', labelsize=14)
viz = FeatureImportances(gs_xgb.best_estimator_.steps[1][1])
viz.fit(X_train, y_train)
viz.poof();
# Out:
# C:\Users\Rachel\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)

# %% [markdown]
# ### Summary of Performance

# %%
lst_metrices = [lr_m, bag_m, rf_m, et_m, ada_m, gb_m, xgb_m]
combine_metrices = pd.concat((items for items in lst_metrices), axis=1, join='inner')
combine_metrices.reset_index()
# Out:
#                     index        lr       bag        rf        et       ada  \
# 0                Accuracy     0.731     0.717     0.740     0.740     0.794
# 1  Misclassification Rate     0.269     0.283     0.260     0.260     0.206
# 2     Sensitivity(Recall)     0.731     0.753     0.725     0.725     0.604
# 3             Specificity     0.731     0.715     0.741     0.741     0.805
# 4               Precision     0.131     0.128     0.134     0.134     0.146
# 5           True Positive   133.000   137.000   132.000   132.000   110.000
# 6          False Positive   885.000   936.000   850.000   850.000   641.000
# 7          False Negative    49.000    45.000    50.000    50.000    72.000
# 8           True Negative 2,400.000 2,349.000 2,435.000 2,435.000 2,644.000
# 9               ROC Score     0.798     0.797     0.825     0.825     0.804
#
#          gb       xgb
# 0     0.798     0.755
# 1     0.202     0.245
# 2     0.648     0.709
# 3     0.807     0.757
# ...
